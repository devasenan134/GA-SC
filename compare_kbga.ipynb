# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
ga_path = 'pickles/ga/'
kbga_path = 'pickles/kbga/amazon/'

# %%
ga_files = ['n_run_az_100fc.pkl', 'n_run_imdb_100fc.pkl', 'n_run_yelp_100fc.pkl']
kbga_files = ['n_run_az_kbga_nokbps.pkl', 'n_run_az_kbga_es50.pkl', 'n_run_az_kbga_cmp.pkl', 'n_run_az_kbga_vp.pkl']

# %% [markdown]
# ## GA Comparison

# %%
with open(ga_path+ga_files[0], 'rb') as gf:
    data = pickle.load(gf)
    x = range(1, 101)
    for n in data:
        y = n[1]    
        plt.plot(x, y)
    plt.title("GAb - Amazon | 100Feature count")
    plt.xlabel('No. of Generations')
    plt.ylabel('Accuracy')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 with open(ga_path+ga_files[0], 'rb') as gf:
#       2     data = pickle.load(gf)
#       3     x = range(1, 101)
#
# File c:\Users\student\anaconda3\envs\dev-ml\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pickles/ga/n_run_az_100fc.pkl'

# %%
with open(ga_path+ga_files[1], 'rb') as gf:
    data = pickle.load(gf)
    x = range(1, 101)
    for n in data:
        y = n[1]    
        plt.plot(x, y)
    plt.title("GAb - IMDB | 100Feature count")
    plt.xlabel('No. of Generations')
    plt.ylabel('Accuracy')
    plt.show()

# %%
with open(ga_path+ga_files[2], 'rb') as gf:
    data = pickle.load(gf)
    x = range(1, 101)
    for n in data:
        y = n[1]    
        plt.plot(x, y)
    plt.title("GAb - Yelp | 100Feature count")
    plt.xlabel('No. of Generations')
    plt.ylabel('Accuracy')
    plt.show()

# %% [markdown]
# ## KBGA Comparison

# %%
with open(kbga_path+kbga_files[0], 'rb') as gf:
    data = pickle.load(gf)
    x = range(1, 101)
    for n in data:
        y = n[1]    
        plt.plot(x, y)
    plt.title("KBGA with no kb-population selection")
    plt.xlabel('No. of Generations')
    plt.ylabel('Accuracy')
    plt.show()

# %%
with open(kbga_path+kbga_files[1], 'rb') as gf:
    data = pickle.load(gf)
    x = range(1, 101)
    for n in data:
        y = n[1]    
        plt.plot(x, y)
    plt.title("KBGA with Elite Selection - 50%")
    plt.xlabel('No. of Generations')
    plt.ylabel('Accuracy')
    plt.show()

# %%
with open(kbga_path+kbga_files[2], 'rb') as gf:
    data = pickle.load(gf)
    x = range(1, 101)
    for n in data:
        y = n[1]    
        plt.plot(x, y)
    plt.title("KBGA with Crossover and Mutation probability")
    plt.xlabel('No. of Generations')
    plt.ylabel('Accuracy')
    plt.show()

# %%
with open(kbga_path+kbga_files[3], 'rb') as gf:
    data = pickle.load(gf)
    x = range(1, 101)
    for n in data:
        y = n[1]    
        plt.plot(x, y)
    plt.title("KBGA with Varient pressure")
    plt.xlabel('No. of Generations')
    plt.ylabel('Accuracy')
    plt.show()
