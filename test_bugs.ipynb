# %%
import numpy as np
import pandas as pd

# %%
crossover_pop = [0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.804, 0.804, 0.804, 0.804, 0.804, 0.804, 0.804, 0.804, 0.8, 0.8, 0.8, 0.8, 0.796, 0.796, 0.796, 0.792, 0.792, 0.792, 0.792, 0.788, 0.784, 0.76, 0.748, 0.716]
mutation_parents = [0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812]
mutation_pop = [0.824, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.816, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.808, 0.804, 0.804, 0.804, 0.804, 0.804, 0.804, 0.804, 0.804, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.796, 0.796, 0.796, 0.792, 0.792, 0.792, 0.792, 0.792, 0.788, 0.788, 0.788, 0.788, 0.788, 0.788, 0.784, 0.784, 0.78, 0.78, 0.78, 0.78, 0.78, 0.776, 0.776, 0.772, 0.772, 0.772, 0.764, 0.764, 0.76, 0.76, 0.756, 0.752, 0.752, 0.748, 0.744, 0.74, 0.732, 0.704, 0.704]

# %%
print(crossover_pop[:80] == mutation_parents)
# Out:
# True

# %%
i=j=0
while j < len(mutation_parents):
    if mutation_pop[i] == mutation_parents[j]:
        print(i, mutation_pop[i], mutation_parents[j])
        j+=1
    else:
        print(i, mutation_pop[i]) 
    i+=1
while i < len(mutation_pop):
    print(i, mutation_pop[i]) 
    i+=1
# Out:
# 0 0.824
# 1 0.82 0.82
# 2 0.82 0.82
# 3 0.82 0.82
# 4 0.82 0.82
# 5 0.82 0.82
# 6 0.82 0.82
# 7 0.82 0.82
# 8 0.82 0.82
# 9 0.82
# 10 0.816 0.816
# 11 0.816 0.816
# 12 0.816 0.816
# 13 0.816 0.816
# 14 0.816 0.816
# 15 0.816 0.816
# 16 0.816 0.816
# 17 0.816 0.816
# 18 0.816 0.816
# 19 0.816 0.816
# 20 0.816 0.816
# 21 0.816 0.816
# 22 0.816 0.816
# 23 0.816 0.816
# 24 0.816 0.816
# 25 0.816 0.816
# 26 0.816 0.816
# 27 0.816 0.816
# 28 0.816 0.816
# 29 0.816 0.816
# 30 0.816 0.816
# 31 0.816 0.816
# 32 0.816 0.816
# 33 0.816 0.816
# 34 0.816 0.816
# 35 0.816 0.816
# 36 0.816 0.816
# 37 0.816 0.816
# 38 0.816 0.816
# 39 0.816 0.816
# 40 0.816 0.816
# 41 0.816 0.816
# 42 0.816 0.816
# 43 0.816 0.816
# 44 0.816 0.816
# 45 0.816 0.816
# 46 0.816 0.816
# 47 0.816 0.816
# 48 0.816 0.816
# 49 0.816 0.816
# 50 0.816 0.816
# 51 0.816 0.816
# 52 0.816
# 53 0.816
# 54 0.812 0.812
# 55 0.812 0.812
# 56 0.812 0.812
# 57 0.812 0.812
# 58 0.812 0.812
# 59 0.812 0.812
# 60 0.812 0.812
# ...

# %% [markdown]
# The problem is that, the numpy array objects are mutable, hence the values are used by referencing the original values.

# %%
x = [np.array(1), np.array(2), np.array(3), np.array(4), np.array(5), np.array(6)]
y = x.copy()
z = x[2]
z += 19
y.append(z)
y.append(10)
y
# Out:
# [array(1), array(2), array(22), array(4), array(5), array(6), array(22), 10]

# %%
x
# Out:
# [array(1), array(2), array(22), array(4), array(5), array(6)]

# %%
x = [1,2,3,4,5,6]
y = x.copy()
z = x[2]
z += 18
y.append(z)
y
# Out:
# [1, 2, 3, 4, 5, 6, 21]

# %%
x
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x = np.array(10)
y = x
y += 10
y
# Out:
# array(20)

# %%
x
# Out:
# array(20)
